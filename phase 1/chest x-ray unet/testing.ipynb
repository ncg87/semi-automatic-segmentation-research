# %%
from dataset import ChestXRaysSegmentationDataset
import matplotlib.pyplot as plt
import torch

# %%
image_path = 'chest_x-ray/images'
mask_path = 'chest_x-ray/masks'
augumented = True
dataset = ChestXRaysSegmentationDataset(image_path, mask_path, image_size = 256, augumented = augumented)
# Out:
# ...
# 100%|██████████| 704/704 [00:00<?, ?it/s]

# %% [markdown]
# Check if the image and mask match

# %%
a,b = dataset.__getitem__(700)

# %%
plt.imshow(a.permute(1,2,0))

# %%
plt.imshow(b.permute(1,2,0))

# %% [markdown]
# yes they do

# %%
print(a.shape, b.shape)
# Out:
# torch.Size([3, 256, 256]) torch.Size([1, 256, 256])

# %%
dataloader = torch.utils.data.DataLoader(dataset=dataset, batch_size=2, shuffle =False, num_workers=2)

# %%
for i in dataloader:
    print(i[0].shape, i[1].shape)
    break
# Out:
# torch.Size([2, 3, 256, 256]) torch.Size([2, 1, 256, 256])
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x000001B6B59CF560>
# Traceback (most recent call last):
#   File "C:\Users\Nicko\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\utils\data\dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "C:\Users\Nicko\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\utils\data\dataloader.py", line 1443, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\multiprocessing\process.py", line 149, in join
#     res = self._popen.wait(timeout)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
dataloader.

# %%
for i, (a, b) in enumerate(dataset):
    print(i, a.shape, b.shape)
# Out:
# 0 torch.Size([3, 256, 256]) torch.Size([1, 256, 256])
# 1 torch.Size([3, 256, 256]) torch.Size([1, 256, 256])
# 2 torch.Size([3, 256, 256]) torch.Size([1, 256, 256])
# 3 torch.Size([3, 256, 256]) torch.Size([1, 256, 256])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 for i, (a, b) in enumerate(dataset):
#       2     print(i, a.shape, b.shape)
#
# File c:\Users\Nicko\vscodeprojects\deep_learning_practice\possibly research\semi-automatic-segmentation-research\chest x-ray unet\dataset.py:45, in ChestXRaysSegmentationDataset.__getitem__(self, idx)
#      43 #scikit image rescaling
#      44 img_rescaled = resize(img, (self.image_size, self.image_size))
# ---> 45 mask_rescaled = resize(mask, (self.image_size, self.image_size))
#      47 # Convert image to PyTorch tensor
#      48 true_img = self.reshape(img_rescaled).to(torch.float32)
#
# ...
