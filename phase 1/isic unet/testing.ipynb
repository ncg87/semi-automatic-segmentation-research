# %%
from dataset import ISICSegmentationDataset
import os
import matplotlib.pyplot as plt

# %% [markdown]
# Training dataset

# %%
# Paths to masks and images
image_path = "./ISIC/images/ISIC2018_Task1-2_Training_Input/"
masks_path = "./ISIC/masks/ISIC2018_Task1_Training_GroundTruth/"
# Size of image
size = 256
# Define dataset
dataset = ISICSegmentationDataset(image_path, masks_path, size)
# Out:
# 100%|██████████| 2594/2594 [00:00<00:00, 1559860.15it/s]
# 100%|██████████| 2594/2594 [00:00<00:00, 1580480.04it/s]

# %% [markdown]
# Testing to see if images are correct/ line up

# %%
a, b = dataset.__getitem__(1500)

# %%
b.shape
# Out:
# torch.Size([1, 256, 256])

# %%
plt.imshow(a.permute(1,2,0))

# %%
plt.imshow(b.permute(1,2,0))
