# %%
import torch
import matplotlib.pyplot as plt

# %%
a = torch.load('splitA_dices.pt')
print(a)
# Out:
# [0.8147165591900165, 0.8401379952063928, 0.8544055498563327, 0.8527787281916692, 0.8492180017324594, 0.8669017645028921, 0.8649224501389724, 0.8652155949519231, 0.885193971487192, 0.8767934945913461, 0.8733883637648362, 0.8709716796875, 0.8607727931096003, 0.8868604806753305, 0.8900282199566181, 0.9031356664804312, 0.8858520801250751, 0.894283808194674, 0.8774560781625601, 0.8921176470243014, 0.8347890560443585, 0.8969549032358023, 0.8978685232309195, 0.894177510188176, 0.9012651443481445, 0.8993994639470027, 0.9046206841102014, 0.9065994115976187, 0.8986547176654522, 0.9047386462871845, 0.9098695608285757, 0.9030106617854192, 0.9033512702355018, 0.9025488633375901, 0.9124599603506235, 0.9043837327223557, 0.9048360677865835, 0.9114148800189679, 0.9076642990112305, 0.9058840825007513, 0.9130688447218674, 0.9086330120380108, 0.914074604327862, 0.9248696107130784, 0.9127516379723182, 0.9137371503389798, 0.911137580871582, 0.9141009404109075, 0.9142821385310247, 0.9148357097919171, 0.915
# ...

# %%
plt.plot(a)
plt.title('Dice Scores for Split A')
plt.ylim(0, 1)
plt.xlabel('# of Images Trained On')
plt.ylabel('Dice Score')
plt.show()
